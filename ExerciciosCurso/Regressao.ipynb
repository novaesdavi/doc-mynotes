# %%
import pandas as pd
import numpy as nb
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
import scipy.stats as stats
import seaborn as sns

# %%
base = pd.read_csv('./arquivos/mt_cars.csv')
base.head()
base.shape
# Out:
# (32, 12)

# %%
base = base.drop(['Unnamed: 0'], axis=1)

# %%
corr = base.corr()
sns.heatmap(corr,cmap='coolwarm', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
column_pairs = [('mpg', 'cyl'),('mpg', 'disp'),('mpg', 'hp'),('mpg', 'wt'),('mpg', 'drat'),('mpg', 'vs')]
n_plots = len(column_pairs)
fig = axes = plt.subplots(nrows=n_plots, ncols=1, figsize=(6, 4*n_plots))

for i, pair in enumerate(column_pairs):
    x_col, y_col = pair
    sns.scatterplot(x=x_col, y=y_col, data=base, ax=axes[i])
    axes[i].set_title(f'Scatter plot of {y_col} vs {x_col}')
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 7
#       5 for i, pair in enumerate(column_pairs):
#       6     x_col, y_col = pair
# ----> 7     sns.scatterplot(x=x_col, y=y_col, data=base, ax=axes[i])
#       8     axes[i].set_title(f'Scatter plot of {y_col} vs {x_col}')
#       9     plt.tight_layout()
#
# File c:\Users\dnova\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\relational.py:631, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     628 if not p.has_xy_data:
#     629     return ax
# --> 631 p._attach(ax)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#
# File c:\Users\dnova\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:1101, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1097 # Simplest cases are that we have a single axes, all axes are shared,
#    1098 # or sharing is only on the orthogonal facet dimension. In these cases,
#    1099 # all datapoints get converted the same way, so use the first axis
#    1100 if share_state is True or share_state == facet_dim[other_var]:
# -> 1101     converter.loc[:] = getattr(ax_list[0], f"{var}axis")
#    1103 else:
#    1104
#    1105     # Next simplest case is when no axes are shared, and we can
#    1106     # use the axis objects within each facet
#    1107     if share_state is False:
#
# AttributeError: 'Figure' object has no attribute 'xaxis'
